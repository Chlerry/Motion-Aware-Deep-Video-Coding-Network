# %%
import numpy as np
from imp import reload
import matplotlib.pyplot as plt

# %%
compression_ratio = [0.021, 0.042, 0.083, 0.125, 0.167]

pred_ssim = [0.525302982738222, 0.583055809458466, 0.624307885610034, 0.675521460132714, 0.686121628649495]
coarse_ssim = [0.539349683798985, 0.634814921156521, 0.719094138172241, 0.792828475186316, 0.849713163726269]
final_ssim = [0.57346751141162, 0.640008752258715, 0.697732880465114, 0.764174022832072, 0.811352196014644]

# %%
pred_padd = [0.5367645288,0.6236748331,0.6976426385,0.7562851859,0.7904163421]
plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net (no padding)')
plt.plot(compression_ratio, coarse_ssim, 'yo-',  label='Prediction Net (padding)')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the prediction (without residue)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
res_padd = [0.5812461513,0.6686451573,0.7615719033,0.8134410783,0.8573432021]

# %%
plt.plot(compression_ratio, pred_padd, 'rs-', label='Prediction Net (padding)')
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Compression Net')
plt.plot(compression_ratio, res_padd, 'go-',  label='Final Decoding (padding)')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (padding)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
gnet5_pre_padd = [0.5340007318,0.6196172634,0.6945288805,0.7521322708,0.7854289986]
gnet5_pre_no1x1_padd = [0.5375075042,0.6249988483,0.6984385695,0.7550304122,0.7874265890]

plt.plot(compression_ratio, gnet5_pre_padd, 'rs-', label='Prediction GNet 5 (padding)')
plt.plot(compression_ratio, gnet5_pre_no1x1_padd, 'bo-', label='Prediction GNet 5 (padding, no 1x1)')
plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
gnet5_res_padd = [0.5803444947,0.6668325216,0.7620467861,0.8134817080,0.8577840828]

plt.plot(compression_ratio, pred_padd, 'rs-', label='Prediction Net (padding)')
plt.plot(compression_ratio, gnet5_pre_no1x1_padd, 'bo-', label='Prediction GNet 5 (padding, no 1x1)')
plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
gnet7_pre_padd = [0.5415318552,0.6266555066,0.6967246655,0.7504601126,0.7820215526]
plt.plot(compression_ratio, pred_padd, 'rs-', label='Prediction Net (padding)')
plt.plot(compression_ratio, gnet7_pre_padd, 'bo-', label='Prediction GNet 7 (padding)')
plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
coarse_noise = [0.5466935053,0.6354035566,0.7249004997,0.7857447093,0.8513789824]
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Compression Net')
plt.plot(compression_ratio, coarse_noise, 'go-',  label='Compression Net (noise)')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (padding)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net')
# plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Compression Net')
# plt.plot(compression_ratio, final_ssim, 'go-',  label='Final Decoding')
# plt.plot(compression_ratio, b1_ssim, 'yo-',  label='B1 with Res Net')
# plt.plot(compression_ratio, b2_ssim, 'ko-',  label='B2 with Res Net')

# plt.plot(compression_ratio[-1:], pred_gnet_ssim, 'ys-', label='Prediction GNet')
# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# Plot the recognition accuracy rate versus different d values for both PCA and FLD
# plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net')
# plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Compression Net')
# plt.plot(compression_ratio, final_ssim, 'go-',  label='Final Decoding')
# plt.plot(compression_ratio, b1_ssim, 'yo-',  label='B1 with Res Net')
# plt.plot(compression_ratio, b2_ssim, 'ko-',  label='B2 with Res Net')
# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_b1_b1model = [0.295439723,0.3517537524,0.3967750224,0.4358548235,0.4356822583]
# pred_b1_bmodel = [0.2973677513,0.3752587874,0.428242013,0.4804474515,0.5025766739]

# plt.plot(compression_ratio, pred_b1_b1model, 'rs-', label='B1 with B1 Model')
# plt.plot(compression_ratio, pred_b1_bmodel, 'bo-',  label='B1 with B Model')

# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_b1_res_bmodel = [0.3579742227,0.4722428761,0.5573479103,0.6257733152,0.6687758402]

# plt.plot(compression_ratio, b1_ssim, 'yo-',  label='B1 with Res Net')
# plt.plot(compression_ratio, pred_b1_res_bmodel, 'ko-',  label='B1 Res with B Model')

# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_b2 = [0.3188903471,0.4063755591,0.4408708171,0.4946594577,0.5197031899]
# pred_b2_bmodel = [0.3018419245,0.3775154769,0.4315091957,0.4773803634,0.5070771317]

# plt.plot(compression_ratio, pred_b2, 'rs-', label='B2 Prediction Net')
# plt.plot(compression_ratio, pred_b2_bmodel, 'bo-',  label='B2 with B Model (B1 with B)')

# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_b2 = [0.3188903471,0.4063755591,0.4408708171,0.4946594577,0.5197031899]
# pred_b2_bmodel2 = [0.309750992,0.408053282,0.443280879,0.4995913102,0.5127325181]

# plt.plot(compression_ratio, pred_b2, 'rs-', label='B2 Prediction Net')
# plt.plot(compression_ratio, pred_b2_bmodel2, 'bo-',  label='B2 with B2 Model (B1 with B)')

# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_with_ground_truth = [0.2977112098,0.3877339924,0.4569769242,0.5110160356,0.5345309936]

# plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net')
# plt.plot(compression_ratio, pred_with_ground_truth, 'bo-',  label='P Net Trained with Ground Truth')

# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_gnet3_ssim = [0.494144767045581,0.528535635312463]
# pred_gnet4_ssim = [0.297422754301567, 0.375282109724537, 0.4473125956897779, 0.505564048158825,0.533639017162079]

# plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net')
# plt.plot(compression_ratio[-2:], pred_gnet3_ssim, 'ys-', label='Prediction GNet 3')
# plt.plot(compression_ratio, pred_gnet4_ssim, 'bo-', label='Prediction GNet 4')
# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# pred_gnet5_ssim = [0.5250642536,0.5951231946,0.6453881897,0.6859593813,0.7049255617]

# plt.plot(compression_ratio, pred_ssim, 'rs-', label='Prediction Net')
# plt.plot(compression_ratio, pred_gnet5_ssim, 'bo-', label='Prediction GNet 5')
# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()

# %%
# res_gnet5_ssim = [0.5761266762,0.6519412376,0.7331572494,0.781982144,0.8150934031]

# plt.plot(compression_ratio, final_ssim, 'go-',  label='Final Decoding')
# plt.plot(compression_ratio, coarse_ssim, 'yo-',  label='Compression Net')
# plt.plot(compression_ratio, res_gnet5_ssim, 'bo-', label='Prediction GNet 5')
# plt.legend(loc = 2)
# plt.title('The SSIM versus compression ratio for the Party Scene')
# plt.xlabel('Compression Ratio')
# plt.ylabel('SSIM')
# plt.show()
