# %%
import numpy as np
from imp import reload
import matplotlib.pyplot as plt

# %%
compression_ratio = [0.021, 0.042, 0.083, 0.125, 0.167]

coarse_ssim = [0.5438694983,0.634609381,0.7260980145,0.7995496112,0.8598860385]
final_ssim = [0.5824938441,0.671034532,0.7659628915,0.8177317529,0.8467393963]
decoded_final_ssim = [0.5793595969,0.6666453757,0.7541140850,0.7990007549,0.8311134745]

# %%
exp1_b1_res = [0.5789878990,0.6794144163,0.7725581256,0.8196212558,0.8347160151]
exp1_b23_res = [0.5790226280,0.6792892398,0.7717757950,0.8126339672,0.8309672192]

exp2_b1_res = [0.5630367704,0.6553614919,0.7318461773,0.7756687236,0.7654853361]
exp2_b23_res = [0.5841407864,0.6845736314,0.7739742034,0.8135082612,0.8281215646]

exp3_b1_res = [0.5747670501,0.6744004174,0.7600595190,0.8044532792,0.8166474879]
exp3_b23_res = [0.5749051562,0.6757119439,0.7575446658,0.7970651742,0.8104537760]

exp4_b1_res = [0.5627040303,0.6543287565,0.7329931690,0.7749951220,0.7680623595]
exp4_b23_res = [0.4023289230,0.4947233233,0.5621544347,0.6408148978,0.5778121592]

# %%
# Experiment 1
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Coarse')
plt.plot(compression_ratio, final_ssim, 'go-',  label='B + Residue')
plt.plot(compression_ratio, exp1_b1_res, 'rs-', label='B1 + Residue')
plt.plot(compression_ratio, exp1_b23_res, 'yo-',  label='B23 + Residue')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (Experiment 1)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# Experiment 2
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Coarse')
plt.plot(compression_ratio, final_ssim, 'go-',  label='B + Residue')
plt.plot(compression_ratio, exp2_b1_res, 'rs-', label='B1 + Residue')
plt.plot(compression_ratio, exp2_b23_res, 'yo-',  label='B23 + Resdiue')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (Experiment 2)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# Experiment 3
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Coarse')
plt.plot(compression_ratio, decoded_final_ssim, 'go-',  label='B + Residue')
plt.plot(compression_ratio, exp3_b1_res, 'rs-', label='B1 + Residue')
plt.plot(compression_ratio, exp3_b23_res, 'yo-',  label='B23 + Residue')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (Experiment 3)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# Experiment 4
plt.plot(compression_ratio, coarse_ssim, 'bo-',  label='Coarse')
plt.plot(compression_ratio, decoded_final_ssim, 'go-',  label='B + Residue')
plt.plot(compression_ratio, exp4_b1_res, 'rs-', label='B1 + Residue')
plt.plot(compression_ratio, exp4_b23_res, 'yo-',  label='B23 + Residue')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (Experiment 4)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# B Comparison
plt.plot(compression_ratio, final_ssim, 'bo-',  label='Experiment 1 & 2')
plt.plot(compression_ratio, decoded_final_ssim, 'rs-', label='Experiment 3 & 4')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (B + Residue)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# B1 Comparison
plt.plot(compression_ratio, exp1_b1_res, 'bo-',  label='Experiment 1')
plt.plot(compression_ratio, exp2_b1_res, 'go-',  label='Experiment 2')
plt.plot(compression_ratio, exp3_b1_res, 'rs-',  label='Experiment 3')
plt.plot(compression_ratio, exp4_b1_res, 'yo-',  label='Experiment 4')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (B1 + Residue)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()

# %%
# B23 Comparison
plt.plot(compression_ratio, exp1_b23_res, 'bo-',  label='Experiment 1')
plt.plot(compression_ratio, exp2_b23_res, 'go-',  label='Experiment 2')
plt.plot(compression_ratio, exp3_b23_res, 'rs-',  label='Experiment 3')
plt.plot(compression_ratio, exp4_b23_res, 'yo-',  label='Experiment 4')

plt.legend(loc = 2)
plt.title('The SSIM versus compression ratio for the Party Scene (B23 + Residue)')
plt.xlabel('Compression Ratio')
plt.ylabel('SSIM')
plt.show()
